# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/infilect-task-1/grocerydataset/README.md
# /kaggle/input/infilect-task-1/grocerydataset/annotation.txt
# /kaggle/input/infilect-task-1/grocerydataset/subset.txt
# /kaggle/input/infilect-task-1/grocerydataset/.git/HEAD
# /kaggle/input/infilect-task-1/grocerydataset/.git/index
# /kaggle/input/infilect-task-1/grocerydataset/.git/config
# /kaggle/input/infilect-task-1/grocerydataset/.git/description
# /kaggle/input/infilect-task-1/grocerydataset/.git/packed-refs
# /kaggle/input/infilect-task-1/grocerydataset/.git/logs/HEAD
# /kaggle/input/infilect-task-1/grocerydataset/.git/logs/refs/heads/master
# /kaggle/input/infilect-task-1/grocerydataset/.git/logs/refs/remotes/origin/HEAD
# /kaggle/input/infilect-task-1/grocerydataset/.git/info/exclude
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/e6/4edbef111b45c1e037173c625c96ea64afe475
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/9d/979c34ed282680555fafc19f9cb15632a4a83c
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/10/b7cdfccdd730845646506842c4a42e87198ad0
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/aa/076e75cd685ae13df16cadea7676595f250782
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/92/571fcc76debfa0cdb3850ba5d688fbe3afad69
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/1f/2c631952426b0a562630d75048b5a3743ff9d2
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/00/518811aa8986af4a468e3f57d66aedca92e500
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/63/903968804e18b3788c75a14a062074ef2473af
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/bc/806d2eba2419c525ee9f1983c02ce0ce7cb9a0
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/7c/881fb74768eb9a22d90f417445bf32143a9a42
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/d7/76651b5d6eab1dd7794fb4437c3c3ac1abdd65
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/11/d3ad7beaaed21824c68590151be58841bb042d
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/5c/89f850f9c75a8abc4d7cbb0e46abcee10b3707
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/4a/914ccafe8557fa5373792b77585745d6a1eeac
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/7b/e4ba52a97c4df660ddf4820a4ebcd13d9af245
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/79/fc2b2bc9f113063411518f6380778844475bc2
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/2f/1feefd5d697eb34040d71746c077f5c09227cf
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/fc/0f6803986019df205363ebfe5cd11243062860
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/fc/7b0036098b05cca45a823247c5ff02c715e475
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/9e/989225776a34b587f9d5a85436dd15eb18865a
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/0f/50fc731df8cc486025e84d206c596e793f6132
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/8e/2c74ae3c82b74f1b52deb96131524a1e71adda
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/08/b4cc2e3908efe165985ad8f0742418eae54801
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/b5/5aaa22199cb94384023de7dea9d3618c54abbb
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/26/b951c86c893d05705ae11fb146d17993aae325
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/83/5fa161a67bbfc6d5be7e29128d3b31840402fd
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/58/b2ae1a9101be01e69c17a8c9cde14ebc0e3244
# /kaggle/input/infilect-task-1/grocerydataset/.git/objects/89/e6aaf43bf97be31c0289498cf0046bb460c92e
# /kaggle/input/infilect-task-1/grocerydataset/.git/refs/heads/master
# /kaggle/input/infilect-task-1/grocerydataset/.git/refs/remotes/origin/HEAD
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/commit-msg.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/pre-commit.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/applypatch-msg.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/pre-rebase.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/prepare-commit-msg.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/update.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/pre-push.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/pre-applypatch.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/fsmonitor-watchman.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/post-update.sample
# /kaggle/input/infilect-task-1/grocerydataset/.git/hooks/pre-receive.sample
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P07_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P02_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P06_N3_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P04_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P04_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P04_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P07_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P11_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P02_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P10_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P06_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P02_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P03_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P07_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P07_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N1_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N2_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N3_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P04_N1_S5_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P06_N3_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P07_N1_S6_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P04_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P01_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N1_S5_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P11_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P10_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P03_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P03_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N1_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P02_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P03_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N1_S5_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P06_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P02_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P08_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P03_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P07_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P08_N3_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P01_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P04_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P06_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P02_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P03_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P09_N1_S7_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P02_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P02_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P03_N1_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P06_N3_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P08_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P03_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P01_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P09_N1_S7_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N2_S6_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P01_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P03_N1_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P03_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N3_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P08_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N3_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P04_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P11_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P02_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P08_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P06_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N2_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N1_S6_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P11_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P06_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P04_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P06_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P07_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N5_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P10_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N4_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P08_N3_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P08_N2_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P10_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P04_N5_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P06_N2_S3_3.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P06_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P07_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N1_S5_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P10_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N1_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P08_N4_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P10_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P11_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N2_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N3_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P08_N3_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P02_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N5_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P07_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N3_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N3_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P02_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P03_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P06_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P01_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P07_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P03_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P08_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P02_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P04_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P02_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P06_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P07_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P02_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P02_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N4_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P08_N2_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P07_N1_S3_3.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P03_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P02_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P03_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P03_N3_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N1_S6_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P06_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P02_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P07_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P08_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P08_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P06_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P03_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N1_S6_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P07_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P04_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P07_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P05_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P04_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P04_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P02_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P07_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N1_S4_3.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P04_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P03_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P06_N1_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P06_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P06_N3_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P07_N1_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P02_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P05_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P07_N3_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P07_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P05_N3_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C2_P02_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P08_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P07_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N2_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N2_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P05_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P04_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P12_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P04_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P04_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P07_N2_S3_3.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P01_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P09_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P02_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P02_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P10_N3_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C3_P07_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C4_P08_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/train/C1_P01_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P03_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P06_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P04_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P12_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P06_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P07_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P03_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P02_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N1_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P01_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P02_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P04_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P03_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N2_S4_3.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P07_N1_S6_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P07_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P05_N4_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P08_N3_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P01_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P10_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P12_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P10_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P04_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P07_N1_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P10_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P04_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P05_N2_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P05_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P03_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P06_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P02_N1_S2_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N1_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P08_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P01_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N1_S5_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P12_N1_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P04_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P02_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P06_N2_S3_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P06_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P06_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P06_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P02_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P05_N3_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P03_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P04_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P03_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N2_S4_2.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P08_N2_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P07_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N2_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P01_N1_S4_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P04_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P12_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C3_P01_N1_S5_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P04_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C4_P02_N4_S2_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P05_N3_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N1_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C1_P02_N2_S3_1.JPG
# /kaggle/input/infilect-task-1/ShelfImages/test/C2_P01_N3_S3_1.JPG

# %%
import os
import numpy as np
import cv2
from cv2 import imread, resize, imwrite
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing.image import load_img
import glob
import json
# %matplotlib inline

# %%
IM_EXTENSIONS = ['png', 'jpg', 'bmp']

def load_json(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    return data

def get_best_anchor(anchors, box_wh):
    box_wh = np.array(box_wh)
    best_iou = 0
    best_anchor = 0
    for k, anchor in enumerate(anchors):
        intersect_wh = np.maximum(np.minimum(box_wh, anchor), 0.0)
        intersect_area = intersect_wh[0] * intersect_wh[1]
        box_area = box_wh[0] * box_wh[1]
        anchor_area = anchor[0] * anchor[1]
        iou = intersect_area / (box_area + anchor_area - intersect_area)
        if iou > best_iou:
            best_iou = iou
            best_anchor = k
    return best_anchor

# %%
def update_bbox(img_path, bboxes, shape):
    img = load_img(img_path)
    w, h = img.size
    new_bbox = []
    for bbox in bboxes:
        x1, x2 = bbox[0], bbox[0]+bbox[2]
        y1, y2 = bbox[1], bbox[1]+bbox[3]
        new_bbox.append([x1, y1, x2, y2])
    return new_bbox, (w, h)


ROOT_PATH = os.path.join(os.sep+"kaggle", "input", "infilect-task-1")
ROOT_TRAIN_PATH = os.path.join(ROOT_PATH, "ShelfImages", "train")
ROOT_TEST_PATH = os.path.join(ROOT_PATH, "ShelfImages", "test")
TRAIN_ANNOTATIAONS = []
TEST_ANNOTATIONS = []
with open(os.path.join(ROOT_PATH, "grocerydataset", "annotation.txt")) as f:
    for line in f.readlines():
        a = line.split()
        bboxes = []
        for i in range(int(a[1])):
            bboxes.append([int(j) for j in a[i*5 + 2: i*5+6]])
        img = {}
        if os.path.exists(os.path.join(ROOT_TRAIN_PATH, a[0])):
            img['filename'] = os.path.join(ROOT_TRAIN_PATH, a[0])
            bb, shape = update_bbox(os.path.join(ROOT_TRAIN_PATH, a[0]), bboxes, (416, 416))
            img['width'] = shape[0]
            img['height'] = shape[1]
            img['object'] = []
            for b in bb:
                obj = {}
                obj['name'] = "pack"
                obj['xmin'], obj['ymin'], obj['xmax'], obj['ymax'] = b
                img['object'] += [obj]
                
            TRAIN_ANNOTATIAONS += [img]
        if os.path.exists(os.path.join(ROOT_TEST_PATH, a[0])):
            img['filename'] = os.path.join(ROOT_TEST_PATH, a[0])
            bb, shape = update_bbox(os.path.join(ROOT_TEST_PATH, a[0]), bboxes, (416, 416))
            img['width'] = shape[0]
            img['height'] = shape[1]
            img['object'] = []
            for b in bb:
                obj = {}
                obj['name'] = "pack"
                obj['xmin'], obj['ymin'], obj['xmax'], obj['ymax'] = b
                img['object'] += [obj]
            
            TEST_ANNOTATIONS += [img]

# %%
def iou(b1, b2):
    l1, l2 = b1[0] - int(0.5 * b1[2]), b2[0] - int(0.5 * b2[2])
    u1, u2 = l1 + b1[2] - 1, l2 + b2[2] - 1
    intersection_w = max(0, min(u1, u2) - max(l1, l2) + 1)
    if intersection_w == 0:
        return 0
    l1, l2 = b1[1] - int(0.5 * b1[3]), b2[1] - int(0.5 * b2[3])
    u1, u2 = l1 + b1[3] - 1, l2 + b2[3] - 1
    intersection_h = max(0, min(u1, u2) - max(l1, l2) + 1)
    intersection = intersection_w * intersection_h
    if intersection == 0:
        return 0

    union = b1[2] * b1[3] + b2[2] * b2[3] - intersection
    if union == 0:
        raise ValueError('Union value must not be a zero or negative number. (boxes: {}, {})'.format(b1, b2))

    return intersection / union

def kmeans_iou(boxes, k, n_iter=10):
    n_boxes = len(boxes)
    if k > n_boxes:
        raise ValueError('k({}) must be less than or equal to the number of boxes({}).'.format(k, n_boxes))

    # Update clusters and centroids alternately.
    centroids = boxes[np.random.choice(n_boxes, k, replace=False)]
    for _ in range(n_iter):
        cluster_indices = np.array([np.argmax([iou(b, c) for c in centroids]) for b in boxes])
        for i in range(k):
            if np.count_nonzero(cluster_indices == i) == 0:
                print(i)
        centroids = [np.mean(boxes[cluster_indices == i], axis=0) for i in range(k)]

    return np.array(centroids)

boxes = []
for annots in TRAIN_ANNOTATIAONS:
    for obj in annots['object']:
        x_min, x_max, y_min, y_max = obj['xmin'], obj['xmax'], obj['ymin'], obj['ymax']
        center_x, center_y = (x_max + x_min) * 0.5, (y_max + y_min) * 0.5
        width, height = x_max - x_min + 1, y_max - y_min + 1
        boxes.append([center_x, center_y, width, height])

        
boxes = np.array(boxes, dtype=np.float32)
anchors = kmeans_iou(boxes, 1, 10)[:, 2:]
print(anchors)
# Out:
# [[202.21478 309.0017 ]]

# %%
def read_data(annotations, image_size, pixels_per_grid=32, no_label=False):
    class_map = {0:'pack'}
    num_classes = 1 #len(class_map)
    grid_h, grid_w = [image_size[i] // pixels_per_grid for i in range(2)]
    images = []
    labels = []

    for annotes in annotations:
        im_path = annotes['filename']
        # load image and resize image
        im = imread(im_path)
        im = np.array(im, dtype=np.float32)
        im_origina_sizes = im.shape[:2]
        im = resize(im, (image_size[1], image_size[0]))
        if len(im.shape) == 2:
            im = np.expand_dims(im, 2)
            im = np.concatenate([im, im, im], -1)
        images.append(im)

        if no_label:
            labels.append(0)
            continue
        label = np.zeros((grid_h, grid_w, len(anchors), 5 + num_classes))
        for obj in annotes['object']:
            x_min, x_max, y_min, y_max = obj['xmin'], obj['xmax'], obj['ymin'], obj['ymax']
            oh, ow = im_origina_sizes
            
            x_min, y_min, x_max, y_max = x_min / ow, y_min / oh, x_max / ow, y_max / oh
            x_min, y_min, x_max, y_max = np.clip([x_min, y_min, x_max, y_max], 0, 1)
            
            anchor_boxes = np.array(anchors) / np.array([ow, oh])
            best_anchor = get_best_anchor(
                anchor_boxes, [x_max - x_min, y_max - y_min])
            cx = int(np.floor(0.5 * (x_min + x_max) * grid_w))
            cy = int(np.floor(0.5 * (y_min + y_max) * grid_h))
            label[cy, cx, best_anchor, 0:4] = [x_min, y_min, x_max, y_max]
            label[cy, cx, best_anchor, 4] = 1.0
            label[cy, cx, best_anchor, 5] = 1.0
        labels.append(label)

    X_set = np.array(images, dtype=np.float32)
    y_set = np.array(labels, dtype=np.float32)

    return X_set, y_set

# %%
IM_SIZE = (416, 416)
NUM_CLASSES = 1
VALID_RATIO = 0.1
X_train, y_train = read_data(TRAIN_ANNOTATIAONS, IM_SIZE)

# %%
X_test, y_test = read_data(TEST_ANNOTATIONS, IM_SIZE)

# %%
class DataSet(object):

    def __init__(self, images, labels=None):
        if labels is not None:
            assert images.shape[0] == labels.shape[0],\
                ('Number of examples mismatch, between images and labels')
        self._num_examples = images.shape[0]
        self._images = images
        self._labels = labels  # NOTE: this can be None, if not given.
        # image/label indices(can be permuted)
        self._indices = np.arange(self._num_examples, dtype=np.uint)
        self._reset()

    def _reset(self):
        """Reset some variables."""
        self._epochs_completed = 0
        self._index_in_epoch = 0

    @property
    def images(self):
        return self._images

    @property
    def labels(self):
        return self._labels

    @property
    def num_examples(self):
        return self._num_examples

    def sample_batch(self, batch_size, shuffle=True):
        if shuffle:
            indices = np.random.choice(self._num_examples, batch_size)
        else:
            indices = np.arange(batch_size)
        batch_images = self._images[indices]
        if self._labels is not None:
            batch_labels = self._labels[indices]
        else:
            batch_labels = None
        return batch_images, batch_labels

    def next_batch(self, batch_size, shuffle=True):
        start_index = self._index_in_epoch

        # Shuffle the dataset, for the first epoch
        if self._epochs_completed == 0 and start_index == 0 and shuffle:
            np.random.shuffle(self._indices)

        # Go to the next epoch, if current index goes beyond the total number
        # of examples
        if start_index + batch_size > self._num_examples:
            # Increment the number of epochs completed
            self._epochs_completed += 1
            # Get the rest examples in this epoch
            rest_num_examples = self._num_examples - start_index
            indices_rest_part = self._indices[start_index:self._num_examples]

            # Shuffle the dataset, after finishing a single epoch
            if shuffle:
                np.random.shuffle(self._indices)

            # Start the next epoch
            start_index = 0
            self._index_in_epoch = batch_size - rest_num_examples
            end_index = self._index_in_epoch
            indices_new_part = self._indices[start_index:end_index]

            images_rest_part = self._images[indices_rest_part]
            images_new_part = self._images[indices_new_part]
            batch_images = np.concatenate(
                (images_rest_part, images_new_part), axis=0)
            if self._labels is not None:
                labels_rest_part = self._labels[indices_rest_part]
                labels_new_part = self._labels[indices_new_part]
                batch_labels = np.concatenate(
                    (labels_rest_part, labels_new_part), axis=0)
            else:
                batch_labels = None
        else:
            self._index_in_epoch += batch_size
            end_index = self._index_in_epoch
            indices = self._indices[start_index:end_index]
            batch_images = self._images[indices]
            if self._labels is not None:
                batch_labels = self._labels[indices]
            else:
                batch_labels = None

        return batch_images, batch_labels

# %%
train_set = DataSet(X_train, y_train)
test_set = DataSet(X_test, y_test)

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
def conv_layer(x, filters, kernel_size, strides, padding='SAME', use_bias=True, **kwargs):
    weights_stddev = kwargs.pop('weights_stddev', 0.01)
    return tf.layers.conv2d(
        x,            
        filters,
        kernel_size, 
        strides, 
        padding, 
        kernel_initializer=tf.random_normal_initializer(stddev=weights_stddev), 
        use_bias=use_bias
    )

def batchNormalization(x, is_train):
    return tf.layers.batch_normalization(
        x, 
        training=is_train, 
        momentum=0.99, 
        epsilon=0.001, 
        center=True, 
        scale=True
    )

def conv_bn_relu(x, filters, kernel_size, is_train, strides=(1, 1), padding='SAME', relu=True):
    conv = conv_layer(x, filters, kernel_size, strides, padding, use_bias=False)
    bn = batchNormalization(conv, is_train)
    if relu:
        return tf.nn.leaky_relu(bn, alpha=0.1)
    else:
        return bn

def max_pool(x, side_l, stride, padding='SAME'):
    return tf.nn.max_pool(x, ksize=[1, side_l, side_l, 1],
                          strides=[1, stride, stride, 1], padding=padding)

# %%
input_shape = list(IM_SIZE) + [3]
num_classes = NUM_CLASSES
grid_size = [x // 32 for x in input_shape[:2]]
num_anchors = len(anchors)

# Prepare Input
X = tf.placeholder(tf.float32, [None] + input_shape)
y = tf.placeholder(tf.float32, [None] + grid_size + [num_anchors] + [5 + num_classes])
is_train = tf.placeholder(tf.bool)

# %%
# init build graph
graph = tf.get_default_graph()
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# %%
d = dict()

#conv1 - batch_norm1 - leaky_relu1 - pool1
with tf.variable_scope('layer1'):
    d['conv1'] = conv_bn_relu(X, 32, (3, 3), is_train)
    d['pool1'] = max_pool(d['conv1'], 2, 2, padding='SAME')
# (416, 416, 3) --> (208, 208, 32)

#conv2 - batch_norm2 - leaky_relu2 - pool2
with tf.variable_scope('layer2'):
    d['conv2'] = conv_bn_relu(d['pool1'], 64, (3, 3), is_train)
    d['pool2'] = max_pool(d['conv2'], 2, 2, padding='SAME')
# (208, 208, 32) --> (104, 104, 64)

#conv3 - batch_norm3 - leaky_relu3
with tf.variable_scope('layer3'):
    d['conv3'] = conv_bn_relu(d['pool2'], 128, (3, 3), is_train)
# (104, 104, 64) --> (104, 104, 128)

#conv4 - batch_norm4 - leaky_relu4
with tf.variable_scope('layer4'):
    d['conv4'] = conv_bn_relu(d['conv3'], 64, (1, 1), is_train)
# (104, 104, 128) --> (104, 104, 64)

#conv5 - batch_norm5 - leaky_relu5 - pool5
with tf.variable_scope('layer5'):
    d['conv5'] = conv_bn_relu(d['conv4'], 128, (3, 3), is_train)
    d['pool5'] = max_pool(d['conv5'], 2, 2, padding='SAME')
# (104, 104, 64) --> (52, 52, 128)

#conv6 - batch_norm6 - leaky_relu6
with tf.variable_scope('layer6'):
    d['conv6'] = conv_bn_relu(d['pool5'], 256, (3, 3), is_train)
# (52, 52, 128) --> (52, 52, 256)

#conv7 - batch_norm7 - leaky_relu7
with tf.variable_scope('layer7'):
    d['conv7'] = conv_bn_relu(d['conv6'], 128, (1, 1), is_train)
# (52, 52, 256) --> (52, 52, 128)

#conv8 - batch_norm8 - leaky_relu8 - pool8
with tf.variable_scope('layer8'):
    d['conv8'] = conv_bn_relu(d['conv7'], 256, (3, 3), is_train)
    d['pool8'] = max_pool(d['conv8'], 2, 2, padding='SAME')
# (52, 52, 128) --> (26, 26, 256)

#conv9 - batch_norm9 - leaky_relu9
with tf.variable_scope('layer9'):
    d['conv9'] = conv_bn_relu(d['pool8'], 512, (3, 3), is_train)
# (26, 26, 256) --> (26, 26, 512)

#conv10 - batch_norm10 - leaky_relu10
with tf.variable_scope('layer10'):
    d['conv10'] = conv_bn_relu(d['conv9'], 256, (1, 1), is_train)
# (26, 26, 512) --> (26, 26, 256)

#conv11 - batch_norm11 - leaky_relu11
with tf.variable_scope('layer11'):
    d['conv11'] = conv_bn_relu(d['conv10'], 512, (3, 3), is_train)
# (26, 26, 256) --> (26, 26, 512)

#conv12 - batch_norm12 - leaky_relu12
with tf.variable_scope('layer12'):
    d['conv12'] = conv_bn_relu(d['conv11'], 256, (1, 1), is_train)
# (26, 26, 512) --> (26, 26, 256)

#conv13 - batch_norm13 - leaky_relu13 - pool13
with tf.variable_scope('layer13'):
    d['conv13'] = conv_bn_relu(d['conv12'], 512, (3, 3), is_train)
    d['pool13'] = max_pool(d['conv13'], 2, 2, padding='SAME')
# (26, 26, 256) --> (13, 13, 512)

#conv14 - batch_norm14 - leaky_relu14
with tf.variable_scope('layer14'):
    d['conv14'] = conv_bn_relu(d['pool13'], 1024, (3, 3), is_train)
# (13, 13, 512) --> (13, 13, 1024)

#conv15 - batch_norm15 - leaky_relu15
with tf.variable_scope('layer15'):
    d['conv15'] = conv_bn_relu(d['conv14'], 512, (1, 1), is_train)
# (13, 13, 1024) --> (13, 13, 512)

#conv16 - batch_norm16 - leaky_relu16
with tf.variable_scope('layer16'):
    d['conv16'] = conv_bn_relu(d['conv15'], 1024, (3, 3), is_train)
# (13, 13, 512) --> (13, 13, 1024)

#conv17 - batch_norm16 - leaky_relu17
with tf.variable_scope('layer17'):
    d['conv17'] = conv_bn_relu(d['conv16'], 512, (1, 1), is_train)
# (13, 13, 1024) --> (13, 13, 512)

#conv18 - batch_norm18 - leaky_relu18
with tf.variable_scope('layer18'):
    d['conv18'] = conv_bn_relu(d['conv17'], 1024, (3, 3), is_train)
# (13, 13, 512) --> (13, 13, 1024)

#conv19 - batch_norm19 - leaky_relu19
with tf.variable_scope('layer19'):
    d['conv19'] = conv_bn_relu(d['conv18'], 1024, (3, 3), is_train)
# (13, 13, 1024) --> (13, 13, 1024)

#Detection Layer
#conv20 - batch_norm20 - leaky_relu20
with tf.variable_scope('layer20'):
    d['conv20'] = conv_bn_relu(d['conv19'], 1024, (3, 3), is_train)
# (13, 13, 1024) --> (13, 13, 1024)

# concatenate layer20 and layer 13 using space to depth
with tf.variable_scope('layer21'):
    d['skip_connection'] = conv_bn_relu(d['conv13'], 64, (1, 1), is_train)
    d['skip_space_to_depth_x2'] = tf.space_to_depth(
        d['skip_connection'], block_size=2)
    d['concat21'] = tf.concat(
        [d['skip_space_to_depth_x2'], d['conv20']], axis=-1)
# (13, 13, 1024) --> (13, 13, 256+1024)

#conv22 - batch_norm22 - leaky_relu22
with tf.variable_scope('layer22'):
    d['conv22'] = conv_bn_relu(d['concat21'], 1024, (3, 3), is_train)
# (13, 13, 1280) --> (13, 13, 1024)

with tf.variable_scope('output_layer'):
    output_channel = num_anchors * (5 + num_classes)
    d['logits'] = conv_layer(d['conv22'], output_channel, (1, 1), (1, 1),
                            padding='SAME', use_bias=True)
    d['pred'] = tf.reshape(
        d['logits'], (-1, grid_size[0], grid_size[1], num_anchors, 5 + num_classes))
# (13, 13, 1024) --> (13, 13, num_anchors , (5 + num_classes))

# %%
logits = d['logits']
pred = d['pred']

# %%
loss_weights = [5, 5, 5, 0.5, 1.0]

grid_h, grid_w = grid_size
grid_wh = np.reshape([grid_w, grid_h], [1, 1, 1, 1, 2]).astype(np.float32)
cxcy = np.transpose([np.tile(np.arange(grid_w), grid_h), 
                     np.repeat(np.arange(grid_h), grid_h)])
cxcy = np.reshape(cxcy, (1, grid_h, grid_w, 1, 2))

txty, twth = pred[..., 0:2], pred[..., 2:4]
confidence = tf.sigmoid(pred[..., 4:5])
class_probs = tf.nn.softmax(pred[..., 5:], axis=-1)\
            if num_classes > 1 else tf.sigmoid(pred[..., 5:])
bxby = tf.sigmoid(txty) + cxcy
pwph = np.reshape(anchors, (1, 1, 1, num_anchors, 2)) / 32
bwbh = tf.exp(twth) * pwph

# calculating for prediction
nxny, nwnh = bxby / grid_wh, bwbh / grid_wh
nx1ny1, nx2ny2 = nxny - 0.5 * nwnh, nxny + 0.5 * nwnh
pred_y = tf.concat((nx1ny1, nx2ny2, confidence, class_probs), axis=-1)

# calculating IoU for metric
num_objects = tf.reduce_sum(y[..., 4:5], axis=[1, 2, 3, 4])
max_nx1ny1 = tf.maximum(y[..., 0:2], nx1ny1)
min_nx2ny2 = tf.minimum(y[..., 2:4], nx2ny2)
intersect_wh = tf.maximum(min_nx2ny2 - max_nx1ny1, 0.0)
intersect_area = tf.reduce_prod(intersect_wh, axis=-1)
intersect_area = tf.where(
    tf.equal(intersect_area, 0.0), tf.zeros_like(intersect_area), intersect_area)
gt_box_area = tf.reduce_prod(y[..., 2:4] - y[..., 0:2], axis=-1)
box_area = tf.reduce_prod(nx2ny2 - nx1ny1, axis=-1)
iou = tf.truediv(intersect_area, (gt_box_area + box_area - intersect_area))

gt_bxby = 0.5 * (y[..., 0:2] + y[..., 2:4]) * grid_wh
gt_bwbh = (y[..., 2:4] - y[..., 0:2]) * grid_wh

resp_mask = y[..., 4:5]
no_resp_mask = 1.0 - resp_mask
#gt_confidence = resp_mask * tf.expand_dims(iou, axis=-1)
gt_confidence = resp_mask
gt_class_probs = y[..., 5:]

loss_bxby = loss_weights[0] * resp_mask * tf.square(gt_bxby - bxby)
loss_bwbh = loss_weights[1] * resp_mask * tf.square(tf.sqrt(gt_bwbh) - tf.sqrt(bwbh))
loss_resp_conf = loss_weights[2] * resp_mask * tf.square(gt_confidence - confidence)
loss_no_resp_conf = loss_weights[3] * no_resp_mask * tf.square(gt_confidence - confidence)
loss_class_probs = loss_weights[4] * resp_mask * tf.square(gt_class_probs - class_probs)

merged_loss = tf.concat((
                        loss_bxby,
                        loss_bwbh,
                        loss_resp_conf,
                        loss_no_resp_conf,
                        loss_class_probs
                        ),
                        axis=-1)
total_loss = tf.reduce_sum(merged_loss, axis=-1)
total_loss = tf.reduce_mean(total_loss)

# %%
def nms(boxes, conf_thres=0.2, iou_thres=0.5):
    x1 = boxes[..., 0]
    y1 = boxes[..., 1]
    x2 = boxes[..., 2]
    y2 = boxes[..., 3]
    areas = (x2 - x1) * (y2 - y1)
    scores = boxes[..., 4]

    keep = []
    order = scores.argsort()[::-1]

    while order.size > 0:
        i = order[0]
        keep.append(i)
        xx1 = np.maximum(x1[i], x1[order[1:]])
        yy1 = np.maximum(y1[i], y1[order[1:]])
        xx2 = np.minimum(x2[i], x2[order[1:]])
        yy2 = np.minimum(y2[i], y2[order[1:]])

        w = np.maximum(0.0, xx2 - xx1)
        h = np.maximum(0.0, yy2 - yy1)
        inter = w * h
        ovr = inter / (areas[i] + areas[order[1:]] - inter)

        inds = np.where(ovr <= iou_thres)[0]
        order = order[inds + 1]

    nms_box = []
    for idx in range(len(boxes)):
        if idx in keep and boxes[idx, 4] > conf_thres:
            nms_box.append(boxes[idx])
        else:
            nms_box.append(np.zeros(boxes.shape[-1]))
    boxes = np.array(nms_box)
    return boxes

def convert_boxes(input_y):
    is_batch = len(input_y.shape) == 5
    if not is_batch:
        input_y = np.expand_dims(input_y, 0)
    boxes = np.reshape(input_y, (input_y.shape[0], -1, input_y.shape[-1]))
    if is_batch:
        return np.array(boxes)
    else:
        return boxes[0]

def predict_nms_boxes(input_y, conf_thres=0.2, iou_thres=0.5):
    is_batch = len(input_y.shape) == 5
    if not is_batch:
        input_y = np.expand_dims(input_y, 0)
    boxes = np.reshape(input_y, (input_y.shape[0], -1, input_y.shape[-1]))
    nms_boxes = []
    for box in boxes:
        nms_box = nms(box, conf_thres, iou_thres)
        nms_boxes.append(nms_box)
    if is_batch:
        return np.array(nms_boxes)
    else:
        return nms_boxes[0]

def cal_map(gt_bboxes, bboxes,thresholds=[0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75]):
    m_tot = 0.0
    for iou_thres in thresholds:
        p = 0
        tp = 0
        fn = 0
        fp = 0
        for idx, (gt, bbox) in enumerate(zip(gt_bboxes, bboxes)):
            gt = gt[np.nonzero(np.any(gt > 0, axis=1))]
            bbox = bbox[np.nonzero(np.any(bbox > 0, axis=1))]
            p += len(gt)
            if bbox.size == 0:
                continue
            iou = _cal_overlap(gt, bbox)
            predicted_class = np.argmax(bbox[...,5:], axis=-1)
            for g, area in zip(gt, iou):
                gt_c = np.argmax(g[5:])
                idx = np.argmax(area)
                if np.max(area) > iou_thres and predicted_class[idx] == gt_c:
                    tp += 1
                else:
                    fp += 1
        fn = p - tp
        m = tp / (tp + fp)
        m_tot+=m
    return m_tot/len(thresholds)

def _cal_overlap(a, b):
    area = (b[:, 2] - b[:, 0]) * (b[:, 3] - b[:, 1])

    iw = np.minimum(np.expand_dims(a[:, 2], axis=1), b[:, 2]) - \
        np.maximum(np.expand_dims(a[:, 0], axis=1), b[:, 0])
    ih = np.minimum(np.expand_dims(a[:, 3], axis=1), b[:, 3]) - \
        np.maximum(np.expand_dims(a[:, 1], axis=1), b[:, 1])

    iw = np.maximum(iw, 0)
    ih = np.maximum(ih, 0)
    intersection = iw * ih

    ua = np.expand_dims((a[:, 2] - a[:, 0]) *
                        (a[:, 3] - a[:, 1]), axis=1) + area - intersection

    ua = np.maximum(ua, np.finfo(float).eps)

    return intersection / ua

# %%
def score(y_true, y_pred, **kwargs):
    """Compute Recall for a given predicted bboxes"""
    nms_flag = kwargs.pop('nms_flag', True)
    if nms_flag:
        bboxes = predict_nms_boxes(y_pred)
    else:
        bboxes = convert_boxes(y_pred)
    gt_bboxes = convert_boxes(y_true)
    score = cal_map(gt_bboxes, bboxes)
    return score

def predict(sess, dataset, **kwargs):
    batch_size = kwargs.pop('batch_size', 16)
    pred_size = dataset.num_examples
    num_steps = pred_size // batch_size
    flag = int(bool(pred_size % batch_size))
    # Start prediction loop
    _y_pred = []
    for i in range(num_steps + flag):
        if i == num_steps and flag:
            _batch_size = pred_size - num_steps * batch_size
        else:
            _batch_size = batch_size
        X_true, _ = dataset.next_batch(_batch_size, shuffle=False)

        # Compute predictions
        y_pred = sess.run(pred_y, feed_dict={
                          X: X_true, is_train: False})

        _y_pred.append(y_pred)
    _y_pred = np.concatenate(_y_pred, axis=0)
    return _y_pred

# %%
sess = tf.Session(graph=graph, config=config)
saver = tf.train.Saver()

# %%
# Set hyperparameters for training
batch_size = 2
num_epochs = 100
learning_rate = 1e-4
eps = 1e-3
num_eval = 128

# %%
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
update_vars = tf.trainable_variables()
with tf.control_dependencies(extra_update_ops):
    train_op = tf.train.AdamOptimizer(learning_rate=learning_rate).\
                minimize(total_loss, var_list=update_vars)

# %%
sess.run(tf.global_variables_initializer())

# %%
train_size = train_set.num_examples
num_steps_per_epoch = train_size // batch_size
num_steps = num_epochs * num_steps_per_epoch

# %%
curr_epoch = 1
best_score = 0
curr_score = 0
# Start training loop
for i in range(num_steps):
    X_true, y_true = train_set.next_batch(batch_size, shuffle=True)
    _, loss, y_pred = sess.run([train_op, total_loss, pred_y],
                              feed_dict={X:X_true, y: y_true, is_train: True})
    if (i+1) % num_eval == 0:
        step_score = score(y_true, y_pred)
        eval_y_pred = predict(sess, test_set)
        eval_score = score(test_set.labels, eval_y_pred)
        print('[epoch {}]\tloss: {:.6f} |Train score: {:.6f} |Eval score: {:.6f}'
      .format(curr_epoch, loss, step_score, eval_score))
        curr_score = eval_score

    if curr_score > best_score + eps:
        best_score = curr_score
        saver.save(sess, './yolov2.ckpt')
        
    if (i+1) % num_steps_per_epoch == 0:
        curr_epoch += 1
# Out:
# [epoch 1]	loss: 0.528346 |Train score: 0.165621 |Eval score: 0.134956
# [epoch 2]	loss: 0.246046 |Train score: 0.182867 |Eval score: 0.142398
# [epoch 3]	loss: 0.140552 |Train score: 0.327091 |Eval score: 0.053773
# [epoch 4]	loss: 0.188167 |Train score: 0.279550 |Eval score: 0.174674
# [epoch 5]	loss: 0.106012 |Train score: 0.388712 |Eval score: 0.287776
# [epoch 6]	loss: 0.157795 |Train score: 0.280178 |Eval score: 0.293985
# [epoch 7]	loss: 0.138034 |Train score: 0.357528 |Eval score: 0.400395
# [epoch 8]	loss: 0.116841 |Train score: 0.563765 |Eval score: 0.425923
# [epoch 9]	loss: 0.202485 |Train score: 0.317345 |Eval score: 0.478300
# [epoch 10]	loss: 0.076139 |Train score: 0.491171 |Eval score: 0.479906
# [epoch 10]	loss: 0.084067 |Train score: 0.600447 |Eval score: 0.468188
# [epoch 11]	loss: 0.080769 |Train score: 0.489819 |Eval score: 0.481995
# [epoch 12]	loss: 0.062298 |Train score: 0.656844 |Eval score: 0.471647
# [epoch 13]	loss: 0.106624 |Train score: 0.495534 |Eval score: 0.500736
# [epoch 14]	loss: 0.038844 |Train score: 0.843898 |Eval score: 0.521670
# [epoch 15]	loss: 0.040681 |Train score: 0.874736 |Eval score: 0.524610
# [epoch 16]	loss: 0.070658 |Train score: 0.632657 |Eval score: 0.491666
# [epoch 17]	loss: 0.075083 |Train score: 0.573113 |Eval score: 0.539337
# [epoch 18]	loss: 0.040996 |Train score: 0.836176 |Eval score: 0.497736
# [epoch 19]	loss: 0.036913 |Train score: 0.868826 |Eval score: 0.536496
# [epoch 20]	loss: 0.028292 |Train score: 0.857935 |Eval score: 0.523514
# [epoch 20]	loss: 0.051015 |Train score: 0.842767 |Eval score: 0.543581
# [epoch 21]	loss: 0.017070 |Train score: 0.899969 |Eval score: 0.574844
# [epoch 22]	loss: 0.015897 |Train score: 0.913056 |Eval score: 0.563145
# [epoch 23]	loss: 0.040438 |Train score: 0.839696 |Eval score: 0.547553
# [epoch 24]	loss: 0.039800 |Train score: 0.784041 |Eval score: 0.480072
# [epoch 25]	loss: 0.041303 |Train score: 0.791762 |Eval score: 0.568675
# [epoch 26]	loss: 0.030215 |Train score: 0.932470 |Eval score: 0.600867
 (45, 25, 241),
 (189, 201, 133),
 (163, 80, 189),
 (207, 85, 175),
 (175, 22, 204),
 (216, 148, 44),
 (78, 89, 252),
 (226, 249, 12),
 (148, 45, 130),
 (59, 186, 35),
 (238, 168, 83),
 (146, 21, 120),
 (216, 163, 180),
 (230, 145, 131),
 (224, 47, 4),
 (199, 75, 19),
 (97, 21, 151),
 (192, 156, 239),
 (79, 7, 99),
 (207, 147, 105),
 (165, 233, 220),
 (189, 23, 12),
 (67, 155, 193),
 (15, 131, 244),
 (22, 131, 9),
 (89, 73, 36),
 (28, 164, 104),
 (169, 200, 123),
 (84, 248, 244),
 (171, 223, 253),
 (55, 213, 25),
 (149, 224, 249),
 (149, 103, 110),
 (74, 173, 113),
 (235, 126, 250),
 (137, 167, 83),
 (173, 73, 38),
 (229, 123, 129),
 (0, 47, 240),
 (24, 130, 74),
 (50, 48, 107),
 (30, 5, 217),
 (188, 139, 22),
 (198, 194, 232),
 (219, 34, 239),
 (205, 179, 56),
 (37, 191, 152),
 (33, 27, 56),
 (148, 228, 93),
 (46, 62, 56),
 (218, 152, 158),
 (63, 146, 225),
 (109, 230, 90),
 (80, 41, 222),
 (153, 168, 31),
 (22, 208, 120),
 (45, 124, 109),
 (64, 67, 135),
 (218, 160, 217),
 (17, 113, 55),
 (196, 243, 42),
 (161, 103, 179),
 (99, 34, 208),
 (178, 75, 152),
 (105, 196, 147),
 (156, 158, 6),
 (201, 166, 132),
 (163, 247, 9),
 (31, 245, 43),
 (204, 205, 204),
 (70, 180, 105),
 (151, 133, 29),
 (107, 82, 160),
 (111, 148, 164)]

# %%
def draw_pred_boxes(image, pred_boxes, class_map, text=True, score=False):
    im_h, im_w = image.shape[:2]
    output = image.copy()
    for box in pred_boxes:
        overlay = output.copy()

        class_idx = np.argmax(box[5:])
        color = COLORS[class_idx]
        line_width, alpha = (2, 0.8)
        x_min, x_max = [int(x * im_w) for x in [box[0], box[2]]]
        y_min, y_max = [int(x * im_h) for x in [box[1], box[3]]]
        cv2.rectangle(overlay, (x_min, y_min),
                      (x_max, y_max), color, line_width)
        output = cv2.addWeighted(overlay, alpha, output, 1 - alpha, 0)

        if text:
            p_text = str(round(np.max(box[5:]), 3)) if score else class_map[str(class_idx)]
            y_offset = -6
            text_size = 0.6
            text_line_width = 1
            output = cv2.putText(output, p_text, (x_min + 4, y_min + y_offset),
                                 cv2.FONT_HERSHEY_DUPLEX, text_size, color, text_line_width)
    return output

# %%
saver.restore(sess, './yolov2.ckpt')

# %%
test_y_pred = predict(sess, test_set)
test_score = score(test_set.labels, test_y_pred)

print('Test performance: {}'.format(test_score))
mAP = test_score

test_bboxes = predict_nms_boxes(test_y_pred)
gt_test_bboxes = convert_boxes(test_set.labels)

precision = cal_map(test_bboxes, gt_test_bboxes, thresholds=[0.5])
print(precision)
# Out:
# Test performance: 0.8333157894736842
# 0.8247011952191236

# %%
r_idx = np.random.choice(test_set.num_examples, 1)
test_images = test_set.images[r_idx]
test_pred_y = sess.run(pred_y, feed_dict={X: test_images, is_train: False})

# %%
bboxes = predict_nms_boxes(test_pred_y[0], conf_thres=0.5, iou_thres=0.5)
bboxes = bboxes[np.nonzero(np.any(bboxes > 0, axis=1))]
boxed_img = draw_pred_boxes(test_images[0], bboxes, {'0':'pack'})

# %%
plt.axis("off")
imshow(cv2.cvtColor(boxed_img, cv2.COLOR_BGR2RGB)/255)

# %%
results_dict = {}
for images, annot in zip(test_set.images, TEST_ANNOTATIONS):
    test_pred_y = sess.run(pred_y, feed_dict={X: [images], is_train: False})
    bboxes = predict_nms_boxes(test_pred_y[0], conf_thres=0.5, iou_thres=0.5)
    bboxes = bboxes[np.nonzero(np.any(bboxes > 0, axis=1))]
    results_dict[annot['filename']] = bboxes.shape[0]

# %%
results_dict
# Out:
# {'/kaggle/input/infilect-task-1/ShelfImages/test/C1_P02_N1_S5_1.JPG': 40,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P02_N2_S2_1.JPG': 23,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P02_N2_S3_1.JPG': 28,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N1_S2_1.JPG': 23,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N1_S3_1.JPG': 49,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N1_S4_1.JPG': 31,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N1_S4_2.JPG': 35,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N2_S2_1.JPG': 26,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N2_S3_1.JPG': 35,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P03_N3_S2_1.JPG': 25,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P04_N1_S4_1.JPG': 50,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P04_N3_S3_1.JPG': 39,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P05_N2_S4_2.JPG': 41,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P05_N4_S3_1.JPG': 35,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P06_N1_S3_1.JPG': 33,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P06_N1_S4_1.JPG': 44,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P06_N1_S5_1.JPG': 51,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P06_N3_S3_1.JPG': 37,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P08_N2_S4_1.JPG': 52,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P08_N3_S3_1.JPG': 38,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P10_N1_S3_1.JPG': 30,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P10_N1_S5_1.JPG': 51,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P10_N2_S3_1.JPG': 33,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N1_S3_1.JPG': 27,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N1_S4_2.JPG': 35,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N2_S3_2.JPG': 26,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N2_S4_2.JPG': 38,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P11_N2_S4_3.JPG': 36,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P12_N1_S2_1.JPG': 11,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P12_N1_S3_1.JPG': 24,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P12_N1_S5_1.JPG': 34,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C1_P12_N2_S3_1.JPG': 19,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P01_N1_S4_1.JPG': 50,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P01_N2_S2_1.JPG': 27,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P01_N3_S3_1.JPG': 38,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P02_N1_S3_1.JPG': 36,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P02_N1_S4_1.JPG': 43,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P03_N2_S3_1.JPG': 22,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P04_N3_S2_1.JPG': 24,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P05_N3_S3_1.JPG': 34,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P07_N1_S6_1.JPG': 53,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P07_N2_S2_1.JPG': 18,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C2_P08_N3_S3_2.JPG': 27,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P01_N1_S5_1.JPG': 40,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P01_N2_S3_2.JPG': 24,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P02_N1_S2_2.JPG': 20,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P03_N1_S3_1.JPG': 35,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P03_N2_S4_1.JPG': 45,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P03_N3_S3_1.JPG': 38,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P04_N1_S4_1.JPG': 35,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P04_N1_S5_1.JPG': 42,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P05_N3_S2_1.JPG': 22,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P06_N1_S3_2.JPG': 33,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P06_N2_S3_2.JPG': 33,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C3_P06_N4_S3_1.JPG': 38,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P01_N2_S2_1.JPG': 22,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P02_N4_S2_1.JPG': 25,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P03_N1_S3_1.JPG': 34,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P03_N1_S4_1.JPG': 42,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P04_N1_S3_1.JPG': 28,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P04_N2_S2_1.JPG': 15,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P04_N4_S2_1.JPG': 17,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P05_N2_S2_1.JPG': 22,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P07_N1_S3_1.JPG': 38,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P07_N1_S3_2.JPG': 36,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P07_N3_S3_1.JPG': 39,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N1_S3_1.JPG': 33,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N1_S4_1.JPG': 44,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N1_S5_2.JPG': 52,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N2_S2_1.JPG': 21,
#  '/kaggle/input/infilect-task-1/ShelfImages/test/C4_P08_N3_S3_1.JPG': 35}

# %%
metrics = {
    "mAP" : mAP,
    "precision": precision
}

# %%
with open("metrics.json", "w") as f:
    json.dump(metrics, f)

# %%
with open("results.json", "w") as f:
    json.dump(results_dict, f)
